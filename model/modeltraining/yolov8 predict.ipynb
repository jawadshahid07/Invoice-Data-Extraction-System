# %%
from ultralytics import YOLO

# load the custom model
model = YOLO('yolov8model/weights/best.pt')

results= model(source="yolov8dataset/test/images/202-template2bill-company_png.rf.0bb582b5af721a0467aeab11532bf146.jpg", show = True, conf = 0.4, save = True)
# Out:
# image 1/1 D:\code\invoice-data-extraction-system\yolov8dataset\test\images\202-template2bill-company_png.rf.0bb582b5af721a0467aeab11532bf146.jpg: 640x480 1 BA, 1 BAID, 1 INV, 1 INV_DATE, 1 INV_DATE_ID, 1 INV_ID, 1 SA, 1 SAID, 1 TOTAL, 1 TOTAL_ID, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\detect\predict4
